# %% [markdown]
# # Notebook 03: Feature Extraction
#
# **Goal:** Test ClinicalBERT encoding, lab feature pipeline, vitals feature pipeline

# %%
import sys; sys.path.insert(0, '..')
from configs.paths import PATHS
from configs.model_config import MODEL_CFG
print('ClinNote Notebook 03: Feature Extraction')
# Out:
# ClinNote Notebook 03: Feature Extraction
